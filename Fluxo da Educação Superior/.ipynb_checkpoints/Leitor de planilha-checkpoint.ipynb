# %%
from scipy import stats
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# UsageError: Line magic function `%matplotlib inline` not found.

# %%
df = pd.read_excel('indicadores_trajetoria_educacao_superior_2018_2022.xlsx')

# %%
df
# Out:
#                                                Unnamed: 0  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     ...
# 3       Indicadores de Trajetória dos Alunos nos Curso...
# 4                                                     NaN
# ...                                                   ...
# 164404                                              25352
# 164405                                              25352
# 164406                                              25352
# 164407                                              25352
# 164408            Fonte: Censo da Educação Superior/Inep.
#
#                                    Ministério da Educação Unnamed: 2  \
# 0       Instituto Nacional de Estudos e Pesquisas Educ...        NaN
# 1                                                     NaN        NaN
# ...
